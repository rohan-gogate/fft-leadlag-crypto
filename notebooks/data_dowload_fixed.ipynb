# %%
import pandas as pd
import matplotlib.pyplot as plt
import sys
import os

sys.path.append(os.path.abspath("../src"))

from data_pipeline import load_asset_data, save_to_csv, load_from_csv

# %%
btc = load_asset_data("BTC-USD")
eth = load_asset_data("ETH-USD")
# Out:
# c:\Users\Rohan\Code\FFT-Crypto\fft-leadlag-crypto\src\data_pipeline.py:6: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(ticker, interval=interval, period=period)
# [*********************100%***********************]  1 of 1 completed
# c:\Users\Rohan\Code\FFT-Crypto\fft-leadlag-crypto\src\data_pipeline.py:6: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(ticker, interval=interval, period=period)
# [*********************100%***********************]  1 of 1 completed

# %%
save_to_csv(btc, "BTC-USD")
save_to_csv(eth, "ETH-USD")
# Out:
# Directory data/raw does not exist. Creating it.
# Data for BTC-USD saved to data/raw\BTC-USD.csv
# Data for ETH-USD saved to data/raw\ETH-USD.csv
# 'data/raw\\ETH-USD.csv'

# %%
plt.figure(figsize=(12, 5))
plt.plot(btc.index, btc["Close"], label="BTC-USD")
plt.plot(eth.index, eth["Close"], label="ETH-USD")
plt.title("Price History")
plt.xlabel("Date")
plt.ylabel("Close Price")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
